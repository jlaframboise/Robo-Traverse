# %%
import pandas as pd
import numpy as np
import os
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing
from sklearn.neighbors import KNeighborsClassifier

# %%
folder = "~/Desktop/Design Teams/QMIND"
file = "AllData_4T.csv"

df = pd.read_csv(os.path.join(folder, file))

# %%
df = df.rename(columns={'Unnamed: 0': 'Seq'})
df = df.drop(columns=['Unnamed: 0.1'])
df = df.set_index('Seq')
df.head(10)
# Out:
#      ImuAccelX  ImuAccelXDelta16  ImuAccelXDelta2  ImuAccelXDelta32  \
# Seq
# 0     0.512958          0.429161        -0.110133          0.224756
# 1     0.512958          0.312443        -0.030526         -0.026336
# 2     0.299874          0.063446        -0.213084         -0.208894
# 3     0.396540          0.160112        -0.116418          0.550367
# 4     0.493206          0.422876         0.193332          0.647033
# 5     0.493206          0.588974         0.096666          0.767940
# 6     0.153827         -0.472855        -0.339378          0.238223
# 7     0.461482          0.183755        -0.031723          0.355539
# 8    -0.330998         -0.259771        -0.484826         -0.436942
# 9    -0.330998         -0.748787        -0.792481         -0.694917
#
#      ImuAccelXDelta4  ImuAccelXDelta64  ImuAccelXDelta8  ImuAccelY  \
# Seq
# 0           0.831985          0.084396         0.584185   0.362123
# 1           0.360926          0.084396         0.095170   0.362123
# ...

# %%
print(df.isnull().sum().sum())
df.shape
# Out:
# 0
# (378905, 120)

# %%
# combined_labels = df['Speed'].map(str) + "_" + df['Terrain']
# combined_labels
for col in df.columns:
    print(col)
# Out:
# ImuAccelX
# ImuAccelXDelta16
# ImuAccelXDelta2
# ImuAccelXDelta32
# ImuAccelXDelta4
# ImuAccelXDelta64
# ImuAccelXDelta8
# ImuAccelY
# ImuAccelYDelta16
# ImuAccelYDelta2
# ImuAccelYDelta32
# ImuAccelYDelta4
# ImuAccelYDelta64
# ImuAccelYDelta8
# ImuAccelZ
# ImuAccelZDelta16
# ImuAccelZDelta2
# ImuAccelZDelta32
# ImuAccelZDelta4
# ImuAccelZDelta64
# ImuAccelZDelta8
# ImuAngVelX
# ImuAngVelXDelta16
# ImuAngVelXDelta2
# ImuAngVelXDelta32
# ImuAngVelXDelta4
# ImuAngVelXDelta64
# ImuAngVelXDelta8
# ImuAngVelY
# ImuAngVelYDelta16
# ImuAngVelYDelta2
# ImuAngVelYDelta32
# ImuAngVelYDelta4
# ImuAngVelYDelta64
# ImuAngVelYDelta8
# ImuAngVelZ
# ImuAngVelZDelta16
# ImuAngVelZDelta2
# ImuAngVelZDelta32
# ImuAngVelZDelta4
# ImuAngVelZDelta64
# ImuAngVelZDelta8
# ImuOrientW
# ImuOrientWDelta16
# ImuOrientWDelta2
# ImuOrientWDelta32
# ImuOrientWDelta4
# ImuOrientWDelta64
# ImuOrientWDelta8
# ImuOrientX
# ImuOrientXDelta16
# ImuOrientXDelta2
# ImuOrientXDelta32
# ImuOrientXDelta4
# ImuOrientXDelta64
# ...

# %%
le = preprocessing.LabelEncoder()

# %%
X = df.drop(columns=['Speed', 'Terrain'])
# columnsToKeep = [col for col in df.columns.tolist() if 'Delta' in col and 'Accel' in col]
# X = df[columnsToKeep]
# columnsToDrop = [col for col in X.columns.tolist() if 'Time' in col or 'Odom' in col]
columnsToDrop = [x for x in X.columns.tolist() if 'Time' in x or 'Delta' not in x or 'Orient' in x or 'Pos' in x]
X = X.drop(columns=columnsToDrop)
# y = le.fit_transform(combined_labels)
y = le.fit_transform(df['Terrain'])

# %%
X.columns
# Out:
# Index(['ImuAccelXDelta16', 'ImuAccelXDelta2', 'ImuAccelXDelta32',
#        'ImuAccelXDelta4', 'ImuAccelXDelta64', 'ImuAccelXDelta8',
#        'ImuAccelYDelta16', 'ImuAccelYDelta2', 'ImuAccelYDelta32',
#        'ImuAccelYDelta4', 'ImuAccelYDelta64', 'ImuAccelYDelta8',
#        'ImuAccelZDelta16', 'ImuAccelZDelta2', 'ImuAccelZDelta32',
#        'ImuAccelZDelta4', 'ImuAccelZDelta64', 'ImuAccelZDelta8',
#        'ImuAngVelXDelta16', 'ImuAngVelXDelta2', 'ImuAngVelXDelta32',
#        'ImuAngVelXDelta4', 'ImuAngVelXDelta64', 'ImuAngVelXDelta8',
#        'ImuAngVelYDelta16', 'ImuAngVelYDelta2', 'ImuAngVelYDelta32',
#        'ImuAngVelYDelta4', 'ImuAngVelYDelta64', 'ImuAngVelYDelta8',
#        'ImuAngVelZDelta16', 'ImuAngVelZDelta2', 'ImuAngVelZDelta32',
#        'ImuAngVelZDelta4', 'ImuAngVelZDelta64', 'ImuAngVelZDelta8',
#        'OdomAngZDelta16', 'OdomAngZDelta2', 'OdomAngZDelta32',
#        'OdomAngZDelta4', 'OdomAngZDelta64', 'OdomAngZDelta8',
# ...

# %%
scaler = StandardScaler()

scaledFeatures = scaler.fit_transform(X.values)

X = pd.DataFrame(scaledFeatures, columns = X.columns.tolist())

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)

# %%
model = KNeighborsClassifier(n_neighbors=3)
model.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#                      weights='uniform')

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[10197    26   157    18]
#  [  351  9278   736  1666]
#  [ 2112   303 23256   175]
#  [   20   118    32 27336]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.98      0.88     10398
#            1       0.95      0.77      0.85     12031
#            2       0.96      0.90      0.93     25846
#            3       0.94      0.99      0.96     27506
#
#     accuracy                           0.92     75781
#    macro avg       0.91      0.91      0.91     75781
# weighted avg       0.93      0.92      0.92     75781

# %%
# from sklearn import metrics
# print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
